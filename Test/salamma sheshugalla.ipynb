# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('multilingual_mobile_app_reviews_2025.csv')
df

# %%
df.duplicated().any()

# %%
df.isnull().sum()

# %%
review_text=df['review_text'].mode()[0]
rating=df['rating'].median()
u_country=df['user_country'].mode()[0]
u_gender=df['user_gender'].mode()[0]
app_version=df['app_version'].mode()[0]
for col,val in zip(['review_text','rating','user_country','user_gender','app_version'],[review_text,rating,u_country,u_gender,app_version]):
    df[col]=df[col].fillna(val)

# %%
df.info()

# %%
df['review_id'].nunique()

# %%
reviwed=df.groupby('review_text')['user_id'].nunique()
reviwed

# %%
df.groupby('review_text')['app_name'].sum().head(10)

# %%
df.groupby('app_name')['app_category'].sum().head(10)

# %%
df.groupby('user_id')['review_text'].sum().head(10)

# %%
df.groupby('review_text')['review_language'].sum().head(10)

# %%
df.groupby(by='user_id')['rating'].sum().head(10)

# %%
df.groupby('review_text')['review_date'].sum().head(10)

# %%
df.groupby('user_age')['review_text'].sum()

# %%
df.groupby('user_id')['user_country'].sum().head(10)

# %%
df.groupby('user_id')['user_gender'].sum().head(10)

# %%
df.groupby('review_id')['num_helpful_votes'].sum()

# %%
df['device_type'].unique()

# %%
df['verified_purchase']==['true'].count

# %% [markdown]
# #                                                           Multilingual Mobile App Reviews Dataset Analysis

# %% [markdown]
# review_id → Unique identifier for each review.
#
# user_id → Unique identifier for the user who wrote the review.
#
# app_name → Name of the mobile application being reviewed.
#
# app_category → Category/genre of the app (e.g., Games, Finance, Health).
#
# review_text → Written text of the user’s review.
#
# review_language → Language in which the review is written.
#
# rating → Star rating or numeric score given by the user.
#
# review_date → Date when the review was submitted.
#
# verified_purchase → Whether the review is from a verified purchase (Yes/No).
#
# device_type → Type of device used (e.g., Android, iOS, Tablet).
#
# num_helpful_votes → Number of people who found the review helpful.
#
# user_age → Age of the user writing the review.
#
# user_country → Country of the user.
#
# user_gender → Gender of the user.
#
# app_version → Version of the app being reviewed.

# %%
df.head(10)

# %% [markdown]
# # make observation
#
#
#
# 1. Which factors do you think most strongly influence the rating of an app? Why?
# 2. How might review_language affect the interpretation of user satisfaction?
# 3. Explain how app_version and review_date together can show app improvement or decline.
# 4. Do you think verified_purchase makes reviews more trustworthy? Justify your answer.
# 5. How would you test whether device_type has an impact on app ratings?
# 6. If you had to find which age group is most satisfied, what steps would you follow?
# 7. How would you identify fake or unreliable reviews using num_helpful_votes and review_text?

# %% [markdown]
# # Ans

# %% [markdown]
# 1. venmo  app is most strongly influenced the rating of 3.8 why becacuse  that is Latest update broke some features, please fix  and that is verified by the users and mostley females are using and it is ios device mosty india peoples are using  that is used for productivity purpose

# %% [markdown]
# 2. review language users can  easily und4rstand the system language  like feutures ,sittengs etc

# %% [markdown]
# 3. those apps are latest version  and manufactures added some extrqa features  by every time ,and they released  recently that why mostly peoples were imporved  to show that apps

# %% [markdown]
# 4. no but some verified purchese are did honestly, mostly they didn't verified anything simply they keep as it is for money

# %% [markdown]
# 5. they mension  features  of every devic3e type most of the peoples are using after that they give ratings  by giving rating we will decide that is good  one

# %% [markdown]
# 6. all are  satisfied they fallowed ratings , version and based on device type,app category , features and  review text

# %% [markdown]
# 7. by using verified purchase if it is true  they will check ratings and votes

# %% [markdown]
# # coclusion:
#
# The target is to find out what factors (language, gender, age, purchase status, category, version, device, etc.) most influence user ratings and satisfaction

# %% [markdown]
# 1. Suppose you are an app developer: what insights from this dataset would help you improve
# your app?
# 2. Propose one machine learning project idea using this dataset and describe its expected
# outcome

# %% [markdown]
# # Ans

# %% [markdown]
# 1.  it will helpful to device type, ratings ,language,app_category,votes andversion

# %% [markdown]
# 2.language learning app

# %% [markdown]
# # language reference
#
#
#
# | Code   | Language           |
# | ------ | ------------------ |
# | **no** | Norwegian          |
# | **ru** | Russian            |
# | **es** | Spanish            |
# | **vi** | Vietnamese         |
# | **tl** | Tagalog (Filipino) |
# | **th** | Thai               |
# | **da** | Danish             |
# | **ja** | Japanese           |
# | **ms** | Malay              |
# | **fr** | French             |
# | **it** | Italian            |
# | **nl** | Dutch              |
# | **hi** | Hindi              |
# | **ar** | Arabic             |
# | **zh** | Chinese            |
# | **id** | Indonesian         |
# | **pl** | Polish             |
# | **ko** | Korean             |
# | **sv** | Swedish            |
# | **pt** | Portuguese         |
# | **tr** | Turkish            |
# | **fi** | Finnish            |
# | **de** | German             |
# | **en** | English            |
