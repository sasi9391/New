# %%
import pandas as pd
import numpy as np
import numpy.random as rd

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# 0     29.0000      0      0   24160  211.3375       B5        S         1
# 1      0.9167      1      2  113781  151.5500  C22 C26        S         1
# 2      2.0000      1      2  113781  151.5500  C22 C26        S         0
# 3     30.0000      1      2  113781  151.5500  C22 C26        S         0
# 4     25.0000      1      2  113781  151.5500  C22 C26        S         0
# ...       ...    ...    ...     ...       ...      ...      ...       ...
# 1304  14.5000      1      0    2665   14.4542      NaN        C         0
# 1305      NaN      1      0    2665   14.4542      NaN        C         0
# 1306  26.5000      0      0    2656    7.2250      NaN        C         0
# 1307  27.0000      0      0    2670    7.2250      NaN        C         0
# 1308  29.0000      0      0  315082    7.8750      NaN        S         0
#
# [1309 rows x 11 columns]

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# 0     29.0000      0      0   24160  211.3375       B5        S         1
# 1      0.9167      1      2  113781  151.5500  C22 C26        S         1
# 2      2.0000      1      2  113781  151.5500  C22 C26        S         0
# 3     30.0000      1      2  113781  151.5500  C22 C26        S         0
# 4     25.0000      1      2  113781  151.5500  C22 C26        S         0
# ...       ...    ...    ...     ...       ...      ...      ...       ...
# 1304  14.5000      1      0    2665   14.4542      NaN        C         0
# 1305      NaN      1      0    2665   14.4542      NaN        C         0
# 1306  26.5000      0      0    2656    7.2250      NaN        C         0
# 1307  27.0000      0      0    2670    7.2250      NaN        C         0
# 1308  29.0000      0      0  315082    7.8750      NaN        S         0
#
# [1309 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['pclass', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'survived'],
#       dtype='object')

# %%
# df['family']=df['family_cnt']+1
# df['farepar']=df['fare']/df['family'].fillna(1)

# %%
# df=df.drop(columns='family')

# %%
df.head(2)
# Out:
#    pclass                            name     sex      age  sibsp  parch  \
# 0       1   Allen, Miss. Elisabeth Walton  female  29.0000      0      0
# 1       1  Allison, Master. Hudson Trevor    male   0.9167      1      2
#
#    ticket      fare    cabin embarked  survived
# 0   24160  211.3375       B5        S         1
# 1  113781  151.5500  C22 C26        S         1

# %% [markdown]
# Data cleaning:
# 1. check for duplicates and remove them
# 2. check for missing values and hadle/remove them
# 3. check for invalid dtypes and handle them

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1307 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# Data cleaning columns:
# 1. age
# 2. fare
# 3. cabin
# 4. embarked

# %%
df.isnull().sum()
# Out:
# pclass         0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin       1014
# embarked       2
# survived       0
# dtype: int64

# %%
df['age'].isnull().sum()# it will add  true values only if null values is present then it will give that number
# Out:
# np.int64(263)

# %%
df['embarked'].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
emb_md=df['embarked'].mode()[0]# wn ever ur using mode at that time use index at that time only it filling the values
df['embarked']=df['embarked'].fillna(emb_md)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1046 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1308 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1309 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
import seaborn as sns
sns.boxplot(df,x='age')
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# if outlayer is there then take median
# if outlayer is not there then use mean

# %%
sns.boxplot(df,x='fare')#median
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxplot(df,x='embarked')
# Out:
# <Axes: xlabel='embarked'>

# %%
emb_md=df['embarked'].mode()[0]# wn ever ur using mode at that time use index at that time only it filling the values
# df['embarked']=df['embarked'].fillna(emb_md)# wn ever ur using mode at that time use index at that time only it filling the values
age_med=df['age'].median()
# df['age']=df['age'].fillna(age_med)
fare_med=df['fare'].median()# wn ever ur using mode at that time use index at that time only it filling the values
# df['fare']=df['fare'].fillna(fare_med)

# %% [markdown]
# or

# %%
emb_md=df['embarked'].mode()[0]
age_med=df['age'].median()
fare_med=df['fare'].median()

for col,val in zip(['embarked','age','fare'],[emb_md,age_med,fare_med]):
    df[col]=df[col].fillna(val)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   cabin     295 non-null    object
#  9   embarked  1309 non-null   object
#  10  survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# by using dropna if u want to drop the col after filling the all values of remaining each and every rows

# %%
df.dropna(axis=1)
df=df.dropna(axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1309 non-null   int64
#  1   name      1309 non-null   object
#  2   sex       1309 non-null   object
#  3   age       1309 non-null   float64
#  4   sibsp     1309 non-null   int64
#  5   parch     1309 non-null   int64
#  6   ticket    1309 non-null   object
#  7   fare      1309 non-null   float64
#  8   embarked  1309 non-null   object
#  9   survived  1309 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 102.4+ KB

# %%
df['family_cnt']=df['sibsp']+df['parch']# adding sibling spouse and parent child
df['sibsp']+df['parch']         #column/attributr/property/feature/variable
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
df=df.drop(columns=['sibsp','parch'])

# %%
x=df['ticket'].value_counts()
x==1#only values taken not index,values=aggrigation,index=columns
solo=x[x==1].index
solo
# Out:
# Index(['680', '13509', 'PC 17473', 'PC 17482', '11774', '110469', '113801',
#        '113501', '112377', '17475',
#        ...
#        '4138', '349247', '111426', '2641', '2673', '364511', '364499',
#        '349216', '383121', '112050'],
#       dtype='object', name='ticket', length=713)

# %%
df['ticket'].isin(solo)#bool values
df.loc[ df['ticket'].isin(solo)]#true records
# Out:
#       pclass                                  name   sex   age    ticket  \
# 5          1                   Anderson, Mr. Harry  male  48.0     19952
# 7          1                Andrews, Mr. Thomas Jr  male  39.0    112050
# 9          1               Artagaveytia, Mr. Ramon  male  71.0  PC 17609
# 14         1  Barkworth, Mr. Algernon Henry Wilson  male  80.0     27042
# 15         1                   Baumann, Mr. John D  male  28.0  PC 17318
# ...      ...                                   ...   ...   ...       ...
# 1301       3                  Youseff, Mr. Gerious  male  45.5      2628
# 1302       3                     Yousif, Mr. Wazli  male  28.0      2647
# 1306       3             Zakarian, Mr. Mapriededer  male  26.5      2656
# 1307       3                   Zakarian, Mr. Ortin  male  27.0      2670
# 1308       3                    Zimmerman, Mr. Leo  male  29.0    315082
#
#          fare embarked  survived  family_cnt
# 5     26.5500        S         1           0
# 7      0.0000        S         0           0
# 9     49.5042        C         0           0
# 14    30.0000        S         1           0
# 15    25.9250        S         0           0
# ...       ...      ...       ...         ...
# 1301   7.2250        C         0           0
# 1302   7.2250        C         0           0
# 1306   7.2250        C         0           0
# 1307   7.2250        C         0           0
# 1308   7.8750        S         0           0
#
# [713 rows x 9 columns]

# %%
def comp_type(row):
    if row['ticket'] in solo:
        return 'solo'
    else:
        if row['family_cnt']==0:
            return 'friends'
        else:
            return 'family'
df['comp_type']=df.apply(comp_type,axis=1)

# %%
df['companion']=5

# %%
import numpy as np
a=np.arange(6)
a>2
# Out:
# array([False, False, False,  True,  True,  True])

# %%
a[a>2]
# Out:
# array([3, 4, 5])

# %%
df['name'].str.split(',')
# Out:
# 0                        [Allen,  Miss. Elisabeth Walton]
# 1                       [Allison,  Master. Hudson Trevor]
# 2                         [Allison,  Miss. Helen Loraine]
# 3                 [Allison,  Mr. Hudson Joshua Creighton]
# 4       [Allison,  Mrs. Hudson J C (Bessie Waldo Danie...
#                               ...
# 1304                              [Zabour,  Miss. Hileni]
# 1305                             [Zabour,  Miss. Thamine]
# 1306                         [Zakarian,  Mr. Mapriededer]
# 1307                               [Zakarian,  Mr. Ortin]
# 1308                                [Zimmerman,  Mr. Leo]
# Name: name, Length: 1309, dtype: object

# %%
# df['name'].str.split(',',expand=True)
df[['lname','tit_fname']]=df['name'].str.split(',',expand=True)
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  ticket      fare embarked  survived  family_cnt comp_type  \
# 0     29.0000   24160  211.3375        S         1           0   friends
# 1      0.9167  113781  151.5500        S         1           3    family
# 2      2.0000  113781  151.5500        S         0           3    family
# 3     30.0000  113781  151.5500        S         0           3    family
# 4     25.0000  113781  151.5500        S         0           3    family
# ...       ...     ...       ...      ...       ...         ...       ...
# 1304  14.5000    2665   14.4542        C         0           1    family
# 1305  28.0000    2665   14.4542        C         0           1    family
# 1306  26.5000    2656    7.2250        C         0           0      solo
# 1307  27.0000    2670    7.2250        C         0           0      solo
# 1308  29.0000  315082    7.8750        S         0           0      solo
#
#       companion      lname                                tit_fname
# 0             5      Allen                   Miss. Elisabeth Walton
# 1             5    Allison                    Master. Hudson Trevor
# 2             5    Allison                      Miss. Helen Loraine
# 3             5    Allison              Mr. Hudson Joshua Creighton
# 4             5    Allison   Mrs. Hudson J C (Bessie Waldo Daniels)
# ...         ...        ...                                      ...
# 1304          5     Zabour                             Miss. Hileni
# 1305          5     Zabour                            Miss. Thamine
# 1306          5   Zakarian                          Mr. Mapriededer
# 1307          5   Zakarian                                Mr. Ortin
# 1308          5  Zimmerman                                  Mr. Leo
#
# [1309 rows x 13 columns]

# %%
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  ticket      fare embarked  survived  family_cnt comp_type  \
# 0     29.0000   24160  211.3375        S         1           0   friends
# 1      0.9167  113781  151.5500        S         1           3    family
# 2      2.0000  113781  151.5500        S         0           3    family
# 3     30.0000  113781  151.5500        S         0           3    family
# 4     25.0000  113781  151.5500        S         0           3    family
# ...       ...     ...       ...      ...       ...         ...       ...
# 1304  14.5000    2665   14.4542        C         0           1    family
# 1305  28.0000    2665   14.4542        C         0           1    family
# 1306  26.5000    2656    7.2250        C         0           0      solo
# 1307  27.0000    2670    7.2250        C         0           0      solo
# 1308  29.0000  315082    7.8750        S         0           0      solo
#
#       companion      lname                                tit_fname
# 0             5      Allen                   Miss. Elisabeth Walton
# 1             5    Allison                    Master. Hudson Trevor
# 2             5    Allison                      Miss. Helen Loraine
# 3             5    Allison              Mr. Hudson Joshua Creighton
# 4             5    Allison   Mrs. Hudson J C (Bessie Waldo Daniels)
# ...         ...        ...                                      ...
# 1304          5     Zabour                             Miss. Hileni
# 1305          5     Zabour                            Miss. Thamine
# 1306          5   Zakarian                          Mr. Mapriededer
# 1307          5   Zakarian                                Mr. Ortin
# 1308          5  Zimmerman                                  Mr. Leo
#
# [1309 rows x 13 columns]

# %%
df['tit_fname'].str.split('.',expand=True)
# Out:
#             0                                   1     2
# 0        Miss                    Elisabeth Walton  None
# 1      Master                       Hudson Trevor  None
# 2        Miss                       Helen Loraine  None
# 3          Mr             Hudson Joshua Creighton  None
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)  None
# ...       ...                                 ...   ...
# 1304     Miss                              Hileni  None
# 1305     Miss                             Thamine  None
# 1306       Mr                         Mapriededer  None
# 1307       Mr                               Ortin  None
# 1308       Mr                                 Leo  None
#
# [1309 rows x 3 columns]

# %%
df['tit_fname'].str.split('.',n=1,expand=True)
# Out:
#             0                                   1
# 0        Miss                    Elisabeth Walton
# 1      Master                       Hudson Trevor
# 2        Miss                       Helen Loraine
# 3          Mr             Hudson Joshua Creighton
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)
# ...       ...                                 ...
# 1304     Miss                              Hileni
# 1305     Miss                             Thamine
# 1306       Mr                         Mapriededer
# 1307       Mr                               Ortin
# 1308       Mr                                 Leo
#
# [1309 rows x 2 columns]

# %%
df[['coutesey_title','fname']]=df['tit_fname'].str.split('.',n=1,expand=True)

# %%
for col in ['coutesey_title','fname','lname']:
    df[col]=df[col].str.strip()

# %%
df=df.drop(columns=['name','tit_fname'])

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df['embarked']=df['embarked'].replace({'S':'Southampton','C':'Cherbourg','Q':'Queenstown'})

# %%
df=df.rename(columns={'sex':'gender'})

# %%
# def psg_crew(row):
#     if row['fare']==0:
#         return 'crew'
#     else:
#         return 'passenger'
# df['psg/crew']=df.apply(psg_crew,axis=1)
#---------------------------------->
crew_members=df.loc[df['fare']==0]

# %%
df.loc[df['fare']==0].index
idx=df.loc[df['fare']==0].index
df=df.drop(idx)

# %%
df.columns
# Out:
# Index(['pclass', 'gender', 'age', 'ticket', 'fare', 'embarked', 'survived',
#        'family_cnt', 'comp_type', 'companion', 'lname', 'coutesey_title',
#        'fname'],
#       dtype='object')

# %%
df
# Out:
#       pclass  gender      age  ticket      fare     embarked  survived  \
# 0          1  female  29.0000   24160  211.3375  Southampton         1
# 1          1    male   0.9167  113781  151.5500  Southampton         1
# 2          1  female   2.0000  113781  151.5500  Southampton         0
# 3          1    male  30.0000  113781  151.5500  Southampton         0
# 4          1  female  25.0000  113781  151.5500  Southampton         0
# ...      ...     ...      ...     ...       ...          ...       ...
# 1304       3  female  14.5000    2665   14.4542    Cherbourg         0
# 1305       3  female  28.0000    2665   14.4542    Cherbourg         0
# 1306       3    male  26.5000    2656    7.2250    Cherbourg         0
# 1307       3    male  27.0000    2670    7.2250    Cherbourg         0
# 1308       3    male  29.0000  315082    7.8750  Southampton         0
#
#       family_cnt comp_type  companion      lname coutesey_title  \
# 0              0   friends          5      Allen           Miss
# 1              3    family          5    Allison         Master
# 2              3    family          5    Allison           Miss
# 3              3    family          5    Allison             Mr
# 4              3    family          5    Allison            Mrs
# ...          ...       ...        ...        ...            ...
# 1304           1    family          5     Zabour           Miss
# 1305           1    family          5     Zabour           Miss
# 1306           0      solo          5   Zakarian             Mr
# 1307           0      solo          5   Zakarian             Mr
# 1308           0      solo          5  Zimmerman             Mr
#
#                                   fname
# 0                      Elisabeth Walton
# 1                         Hudson Trevor
# 2                         Helen Loraine
# 3               Hudson Joshua Creighton
# 4     Hudson J C (Bessie Waldo Daniels)
# ...                                 ...
# 1304                             Hileni
# 1305                            Thamine
# 1306                        Mapriededer
# 1307                              Ortin
# 1308                                Leo
#
# [1292 rows x 13 columns]

# %%
list=['ticket','coutesey_title','fname','lname','gender','age','pclass','family_cnt','comp_type','embarked','fare','survived','companion']
df=df[list]
df=df.reset_index(drop=True)

df
# Out:
#       ticket coutesey_title                              fname      lname  \
# 0      24160           Miss                   Elisabeth Walton      Allen
# 1     113781         Master                      Hudson Trevor    Allison
# 2     113781           Miss                      Helen Loraine    Allison
# 3     113781             Mr            Hudson Joshua Creighton    Allison
# 4     113781            Mrs  Hudson J C (Bessie Waldo Daniels)    Allison
# ...      ...            ...                                ...        ...
# 1287    2665           Miss                             Hileni     Zabour
# 1288    2665           Miss                            Thamine     Zabour
# 1289    2656             Mr                        Mapriededer   Zakarian
# 1290    2670             Mr                              Ortin   Zakarian
# 1291  315082             Mr                                Leo  Zimmerman
#
#       gender      age  pclass  family_cnt comp_type     embarked      fare  \
# 0     female  29.0000       1           0   friends  Southampton  211.3375
# 1       male   0.9167       1           3    family  Southampton  151.5500
# 2     female   2.0000       1           3    family  Southampton  151.5500
# 3       male  30.0000       1           3    family  Southampton  151.5500
# 4     female  25.0000       1           3    family  Southampton  151.5500
# ...      ...      ...     ...         ...       ...          ...       ...
# 1287  female  14.5000       3           1    family    Cherbourg   14.4542
# 1288  female  28.0000       3           1    family    Cherbourg   14.4542
# 1289    male  26.5000       3           0      solo    Cherbourg    7.2250
# 1290    male  27.0000       3           0      solo    Cherbourg    7.2250
# 1291    male  29.0000       3           0      solo  Southampton    7.8750
#
#       survived  companion
# 0            1          5
# 1            1          5
# 2            0          5
# 3            0          5
# 4            0          5
# ...        ...        ...
# 1287         0          5
# 1288         0          5
# 1289         0          5
# 1290         0          5
# 1291         0          5
#
# [1292 rows x 13 columns]

# %%
df.loc[df['fare']==0].shape[0]
# Out:
# 0

# %%
df.loc[df['fare']==0]
# Out:
# Empty DataFrame
# Columns: [ticket, coutesey_title, fname, lname, gender, age, pclass, family_cnt, comp_type, embarked, fare, survived, companion]
# Index: []

# %%
pd.cut(df['age'],bins=[0,3,17,31,60,100],labels=['baby','child','teen_age','adults','senior'])
df['age_category']=pd.cut(df['age'],bins=[0,3,17,31,60,100],labels=['baby','child','teen_age','adults','senior'])

# %%
list=['ticket','fname','lname','gender','age','age_category','pclass','family_cnt','comp_type','embarked','fare','survived','companion']
df=df[list]
df=df.reset_index(drop=True)
crew_members=crew_members.reset_index(drop=True)

# %%
# df['psg/crew']=df['psg/crew']=['passenger']*1309

# %%
df
# Out:
#       ticket                              fname      lname  gender      age  \
# 0      24160                   Elisabeth Walton      Allen  female  29.0000
# 1     113781                      Hudson Trevor    Allison    male   0.9167
# 2     113781                      Helen Loraine    Allison  female   2.0000
# 3     113781            Hudson Joshua Creighton    Allison    male  30.0000
# 4     113781  Hudson J C (Bessie Waldo Daniels)    Allison  female  25.0000
# ...      ...                                ...        ...     ...      ...
# 1287    2665                             Hileni     Zabour  female  14.5000
# 1288    2665                            Thamine     Zabour  female  28.0000
# 1289    2656                        Mapriededer   Zakarian    male  26.5000
# 1290    2670                              Ortin   Zakarian    male  27.0000
# 1291  315082                                Leo  Zimmerman    male  29.0000
#
#      age_category  pclass  family_cnt comp_type     embarked      fare  \
# 0        teen_age       1           0   friends  Southampton  211.3375
# 1            baby       1           3    family  Southampton  151.5500
# 2            baby       1           3    family  Southampton  151.5500
# 3        teen_age       1           3    family  Southampton  151.5500
# 4        teen_age       1           3    family  Southampton  151.5500
# ...           ...     ...         ...       ...          ...       ...
# 1287        child       3           1    family    Cherbourg   14.4542
# 1288     teen_age       3           1    family    Cherbourg   14.4542
# 1289     teen_age       3           0      solo    Cherbourg    7.2250
# 1290     teen_age       3           0      solo    Cherbourg    7.2250
# 1291     teen_age       3           0      solo  Southampton    7.8750
#
#       survived  companion
# 0            1          5
# 1            1          5
# 2            0          5
# 3            0          5
# 4            0          5
# ...        ...        ...
# 1287         0          5
# 1288         0          5
# 1289         0          5
# 1290         0          5
# 1291         0          5
#
# [1292 rows x 13 columns]

# %% [markdown]
# 1. how many passengers(including crew numbers)  are present in the   dataset

# %%
len(df)
df.shape[0]
# Out:
# 1292

# %% [markdown]
# 2. how many crew memmbers are present

# %%
crew_members.shape[0]+df.shape[0]
# Out:
# 1309

# %%
df.shape[0]
# Out:
# 1292

# %%
df.query(" fare==0 ")
# Out:
# Empty DataFrame
# Columns: [ticket, fname, lname, gender, age, age_category, pclass, family_cnt, comp_type, embarked, fare, survived, companion]
# Index: []

# %% [markdown]
# 4. fid the deails of email (fname)

# %%
df['fname']=='Emil'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1287    False
# 1288    False
# 1289    False
# 1290    False
# 1291    False
# Name: fname, Length: 1292, dtype: bool

# %% [markdown]
# 5. get the statistical discription of all the cols

# %%
df.describe()
# Out:
#                age       pclass   family_cnt         fare     survived  \
# count  1292.000000  1292.000000  1292.000000  1292.000000  1292.000000
# mean     29.468008     2.301084     0.895511    33.718995     0.385449
# std      12.953286     0.836743     1.590759    51.938992     0.486890
# min       0.166700     1.000000     0.000000     3.170800     0.000000
# 25%      22.000000     2.000000     0.000000     7.925000     0.000000
# 50%      28.000000     3.000000     0.000000    14.500000     0.000000
# 75%      35.000000     3.000000     1.000000    31.303125     1.000000
# max      80.000000     3.000000    10.000000   512.329200     1.000000
#
#        companion
# count     1292.0
# mean         5.0
# std          0.0
# min          5.0
# 25%          5.0
# 50%          5.0
# 75%          5.0
# max          5.0

# %%
df.groupby(by='gender')

# %% [markdown]
# 1. find the number of passenger each gender

# %% [markdown]
# observation.male passeger is more  compare than famele passenger

# %%
g=df.groupby(by='gender')

# %%
g.agg({'gender':'count'})
# Out:
#         gender
# gender
# female     466
# male       826

# %% [markdown]
# 2. find  gender wise total_fare

# %% [markdown]
# observation : mae psgs paid more than  female psgs

# %%
df.groupby(by='gender').agg({'fare':'sum'})
# Out:
#               fare
# gender
# female  21528.3130
# male    22036.6281

# %%
g.agg({'fare':['max','min']})
# Out:
#             fare
#              max     min
# gender
# female  512.3292  6.7500
# male    512.3292  3.1708

# %% [markdown]
# 3.find no of psgs in each pclass

# %%
#gp+cnt    -->value_counts()  (alternate)
df['pclass'].value_counts()
# Out:
# pclass
# 3    705
# 1    316
# 2    271
# Name: count, dtype: int64

# %% [markdown]
# observation : more psgs are preffering pclass 3

# %% [markdown]
# 4.find the pclass and gender wise count and total fare

# %%
# df[['pclass','gender']].value_counts()
# df.groupby(by=['pclass','gender']).agg({'gender':'count','fare':'sum'})
df.groupby(by=['pclass','gender']).agg({'gender':'count','fare':'sum'})
# Out:
#                gender        fare
# pclass gender
# 1      female     144  15755.3834
#        male       172  12510.0209
# 2      female     106   2462.8917
#        male       165   3403.7457
# 3      female     216   3310.0379
#        male       489   6122.8615

# %% [markdown]
# obseration:
# in pclass 1 ,even  thrugh male count is higher than female,male are paying less
# half of the male and females psgs are present in pclass 3
# based on pclass  they are paying

# %%
df
# Out:
#       ticket                              fname      lname  gender      age  \
# 0      24160                   Elisabeth Walton      Allen  female  29.0000
# 1     113781                      Hudson Trevor    Allison    male   0.9167
# 2     113781                      Helen Loraine    Allison  female   2.0000
# 3     113781            Hudson Joshua Creighton    Allison    male  30.0000
# 4     113781  Hudson J C (Bessie Waldo Daniels)    Allison  female  25.0000
# ...      ...                                ...        ...     ...      ...
# 1287    2665                             Hileni     Zabour  female  14.5000
# 1288    2665                            Thamine     Zabour  female  28.0000
# 1289    2656                        Mapriededer   Zakarian    male  26.5000
# 1290    2670                              Ortin   Zakarian    male  27.0000
# 1291  315082                                Leo  Zimmerman    male  29.0000
#
#      age_category  pclass  family_cnt comp_type     embarked      fare  \
# 0        teen_age       1           0   friends  Southampton  211.3375
# 1            baby       1           3    family  Southampton  151.5500
# 2            baby       1           3    family  Southampton  151.5500
# 3        teen_age       1           3    family  Southampton  151.5500
# 4        teen_age       1           3    family  Southampton  151.5500
# ...           ...     ...         ...       ...          ...       ...
# 1287        child       3           1    family    Cherbourg   14.4542
# 1288     teen_age       3           1    family    Cherbourg   14.4542
# 1289     teen_age       3           0      solo    Cherbourg    7.2250
# 1290     teen_age       3           0      solo    Cherbourg    7.2250
# 1291     teen_age       3           0      solo  Southampton    7.8750
#
#       survived  companion
# 0            1          5
# 1            1          5
# 2            0          5
# 3            0          5
# 4            0          5
# ...        ...        ...
# 1287         0          5
# 1288         0          5
# 1289         0          5
# 1290         0          5
# 1291         0          5
#
# [1292 rows x 13 columns]

# %% [markdown]
# #the age_cate wise  no_of_ psgs and total fare in each pclass

# %%
df.groupby(by=['pclass','age_category']).agg({'age_category':'count','fare':'sum'})
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\1055124320.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(by=['pclass','age_category']).agg({'age_category':'count','fare':'sum'})
#                      age_category        fare
# pclass age_category
# 1      baby                     2    303.1000
#        child                   13   1437.8333
#        teen_age               117  10007.7750
#        adults                 163  14707.3876
#        senior                  21   1809.3084
# 2      baby                    13    368.9126
#        child                   20    611.3208
#        teen_age               140   2894.8749
#        adults                  92   1911.9916
#        senior                   6     79.5375
# 3      baby                    26    542.2166
#        child                   80   1599.5084
#        teen_age               475   5687.3620
#        adults                 118   1550.2582
#        senior                   6     53.5542

# %%
pd.pivot_table(df,index=['age_category'],columns=['pclass'],values='fare',aggfunc=['count','sum'])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\2353269227.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['age_category'],columns=['pclass'],values='fare',aggfunc=['count','sum'])
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\2353269227.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['age_category'],columns=['pclass'],values='fare',aggfunc=['count','sum'])
#              count                   sum
# pclass           1    2    3           1          2          3
# age_category
# baby             2   13   26    303.1000   368.9126   542.2166
# child           13   20   80   1437.8333   611.3208  1599.5084
# teen_age       117  140  475  10007.7750  2894.8749  5687.3620
# adults         163   92  118  14707.3876  1911.9916  1550.2582
# senior          21    6    6   1809.3084    79.5375    53.5542

# %% [markdown]
# obseration: teen_agers are in high in every class
# in pclass 1 adults are more
# in pclass 2 teen are  more
# in pclass 3 teen are more

# %% [markdown]
# the age_cate wise  no_of_ psgs and total fare in each pclass and gender

# %%
df.groupby(by=['pclass','age_category','gender']).agg({'age_category':'count','fare':'sum'})
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\2155241382.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(by=['pclass','age_category','gender']).agg({'age_category':'count','fare':'sum'})
#                             age_category       fare
# pclass age_category gender
# 1      baby         female             1   151.5500
#                     male               1   151.5500
#        child        female             7   681.1167
#                     male               6   756.7166
#        teen_age     female            55  5946.8042
#                     male              62  4060.9708
#        adults       female            75  8407.6167
#                     male              88  6299.7709
#        senior       female             6   568.2958
#                     male              15  1241.0126
# 2      baby         female             4   136.9084
#                     male               9   232.0042
#        child        female            14   367.0708
#                     male               6   244.2500
#        teen_age     female            55  1228.9125
#                     male              85  1665.9624
#        adults       female            33   730.0000
#                     male              59  1181.9916
#        senior       female             0     0.0000
#                     male               6    79.5375
# 3      baby         female            14   251.8374
#                     male              12   290.3792
#        child        female            32   589.2334
#                     male              48  1010.2750
#        teen_age     female           142  1966.2546
#                     male             333  3721.1074
#        adults       female            27   493.1250
#                     male              91  1057.1332
#        senior       female             1     9.5875
#                     male               5    43.9667

# %%
pd.pivot_table(df,index=['pclass','age_category'],columns=['gender'],values='fare',aggfunc=['count','sum'])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\1116152253.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['pclass','age_category'],columns=['gender'],values='fare',aggfunc=['count','sum'])
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\1116152253.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['pclass','age_category'],columns=['gender'],values='fare',aggfunc=['count','sum'])
#                      count             sum
# gender              female male     female       male
# pclass age_category
# 1      baby              1    1   151.5500   151.5500
#        child             7    6   681.1167   756.7166
#        teen_age         55   62  5946.8042  4060.9708
#        adults           75   88  8407.6167  6299.7709
#        senior            6   15   568.2958  1241.0126
# 2      baby              4    9   136.9084   232.0042
#        child            14    6   367.0708   244.2500
#        teen_age         55   85  1228.9125  1665.9624
#        adults           33   59   730.0000  1181.9916
#        senior            0    6     0.0000    79.5375
# 3      baby             14   12   251.8374   290.3792
#        child            32   48   589.2334  1010.2750
#        teen_age        142  333  1966.2546  3721.1074
#        adults           27   91   493.1250  1057.1332
#        senior            1    5     9.5875    43.9667

# %%
g.agg({'gender':'count','fare':['max','min']})
# Out:
#        gender      fare
#         count       max     min
# gender
# female    466  512.3292  6.7500
# male      826  512.3292  3.1708

# %%
df.groupby('gender').agg({'fare':['max','min']})
pd.pivot_table(df,index=['pclass','gender'],aggfunc=['max','min'],values='fare')
# Out:
#                     max      min
#                    fare     fare
# pclass gender
# 1      female  512.3292  25.7000
#        male    512.3292   5.0000
# 2      female   65.0000  10.5000
#        male     73.5000   9.6875
# 3      female   69.5500   6.7500
#        male     69.5500   3.1708

# %% [markdown]
# observation:in first class both females and males are max in every class males are does't paid comparing female

# %% [markdown]
# find the highest and lowest fare paid by male and female in each pclass

# %%
pd.pivot_table(df,index=['pclass','gender'],aggfunc=['max','min'],values='fare')
# Out:
#                     max      min
#                    fare     fare
# pclass gender
# 1      female  512.3292  25.7000
#        male    512.3292   5.0000
# 2      female   65.0000  10.5000
#        male     73.5000   9.6875
# 3      female   69.5500   6.7500
#        male     69.5500   3.1708

# %% [markdown]
# Observation:in 1st & 3rd pclass both gender  are paid same fare  and 2nd class highest male payers are there  & in every pclass lowest male payers are there comapre to females

# %% [markdown]
# 1. find the highest and lowest fare paid by male and female in each age_category

# %%
pd.pivot_table(df,index=['age_category','gender'],aggfunc=['max','min'],values='fare')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\2508177052.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['age_category','gender'],aggfunc=['max','min'],values='fare')
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\2508177052.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['age_category','gender'],aggfunc=['max','min'],values='fare')
#                           max      min
#                          fare     fare
# age_category gender
# baby         female  151.5500  10.4625
#              male    151.5500   8.5167
# child        female  211.3375   7.2250
#              male    262.3750   3.1708
# teen_age     female  263.0000   6.7500
#              male    263.0000   4.0125
# adults       female  512.3292   7.0000
#              male    512.3292   5.0000
# senior       female  221.7792   9.5875
#              male    263.0000   6.2375

# %% [markdown]
# Observation:Based on age category adults are  paying high fare and child males are  paid low

# %% [markdown]
# find the hifghest and lowest fare paid by male and female in each  pclass and age_category

# %%
pd.pivot_table(df,index=['pclass','age_category','gender'],aggfunc=['max','min'],values='fare')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\4172414619.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['pclass','age_category','gender'],aggfunc=['max','min'],values='fare')
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\4172414619.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['pclass','age_category','gender'],aggfunc=['max','min'],values='fare')
#                                  max       min
#                                 fare      fare
# pclass age_category gender
# 1      baby         female  151.5500  151.5500
#                     male    151.5500  151.5500
#        child        female  211.3375   39.4000
#                     male    262.3750   47.1000
#        teen_age     female  263.0000   26.2833
#                     male    263.0000   25.7417
#        adults       female  512.3292   25.7000
#                     male    512.3292    5.0000
#        senior       female  221.7792   26.5500
#                     male    263.0000   26.0000
# 2      baby         female   41.5792   26.0000
#                     male     39.0000   14.5000
#        child        female   39.0000   10.5000
#                     male     73.5000   10.5000
#        teen_age     female   65.0000   10.5000
#                     male     73.5000   10.5000
#        adults       female   65.0000   10.5000
#                     male     73.5000   10.5000
#        senior       male     26.0000    9.6875
# 3      baby         female   31.2750   10.4625
#                     male     46.9000    8.5167
#        child        female   46.9000    7.2250
#                     male     69.5500    3.1708
#        teen_age     female   69.5500    6.7500
#                     male     69.5500    4.0125
#        adults       female   46.9000    7.0000
#                     male     56.4958    6.4375
#        senior       female    9.5875    9.5875
#                     male     14.4542    6.2375

# %% [markdown]
# Obseration:in 1st pclass both genders  are paid highest fare  and 2nd and 3rd pclass both are paid lowest fase

# %% [markdown]
# # what  factors are affecting the survival rate\

# %% [markdown]
# practice

# %%
#pd.pivot_table(df,values='fare')

# %%
pd.pivot_table(df,index='gender',values='fare')
# Out:
#              fare
# gender
# female  46.198097
# male    26.678727

# %%
pd.pivot_table(df,index='gender',aggfunc='sum',values='fare')
# Out:
#               fare
# gender
# female  21528.3130
# male    22036.6281

# %%
pd.pivot_table(df,index=['pclass','gender'],aggfunc='sum',values='fare')
# Out:
#                      fare
# pclass gender
# 1      female  15755.3834
#        male    12510.0209
# 2      female   2462.8917
#        male     3403.7457
# 3      female   3310.0379
#        male     6122.8615

# %%
pd.pivot_table(df,index='pclass',columns='gender',aggfunc='sum',values='fare')
# Out:
# gender      female        male
# pclass
# 1       15755.3834  12510.0209
# 2        2462.8917   3403.7457
# 3        3310.0379   6122.8615

# %%
pd.pivot_table(df,index=['pclass','age_category'],columns='gender',aggfunc='sum',values='fare')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_836\2623200364.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pd.pivot_table(df,index=['pclass','age_category'],columns='gender',aggfunc='sum',values='fare')
# gender                  female       male
# pclass age_category
# 1      baby           151.5500   151.5500
#        child          681.1167   756.7166
#        teen_age      5946.8042  4060.9708
#        adults        8407.6167  6299.7709
#        senior         568.2958  1241.0126
# 2      baby           136.9084   232.0042
#        child          367.0708   244.2500
#        teen_age      1228.9125  1665.9624
#        adults         730.0000  1181.9916
#        senior           0.0000    79.5375
# 3      baby           251.8374   290.3792
#        child          589.2334  1010.2750
#        teen_age      1966.2546  3721.1074
#        adults         493.1250  1057.1332
#        senior           9.5875    43.9667

# %%
df.shape[0]
# Out:
# 1292

# %%
pd.concat([df,crew_members],axis=0)
# Out:
#     ticket                              fname      lname  gender      age  \
# 0    24160                   Elisabeth Walton      Allen  female  29.0000
# 1   113781                      Hudson Trevor    Allison    male   0.9167
# 2   113781                      Helen Loraine    Allison  female   2.0000
# 3   113781            Hudson Joshua Creighton    Allison    male  30.0000
# 4   113781  Hudson J C (Bessie Waldo Daniels)    Allison  female  25.0000
# ..     ...                                ...        ...     ...      ...
# 12  239856                     Ennis Hastings     Watson    male  28.0000
# 13    LINE                             Alfred    Johnson    male  49.0000
# 14    LINE                 William Cahoone Jr    Johnson    male  19.0000
# 15    LINE                             Lionel    Leonard    male  36.0000
# 16    LINE                      William Henry  Tornquist    male  25.0000
#
#    age_category  pclass  family_cnt comp_type     embarked      fare  \
# 0      teen_age       1           0   friends  Southampton  211.3375
# 1          baby       1           3    family  Southampton  151.5500
# 2          baby       1           3    family  Southampton  151.5500
# 3      teen_age       1           3    family  Southampton  151.5500
# 4      teen_age       1           3    family  Southampton  151.5500
# ..          ...     ...         ...       ...          ...       ...
# 12          NaN       2           0      solo  Southampton    0.0000
# 13          NaN       3           0   friends  Southampton    0.0000
# 14          NaN       3           0   friends  Southampton    0.0000
# 15          NaN       3           0   friends  Southampton    0.0000
# 16          NaN       3           0   friends  Southampton    0.0000
#
#     survived  companion coutesey_title
# 0          1          5            NaN
# 1          1          5            NaN
# 2          0          5            NaN
# 3          0          5            NaN
# 4          0          5            NaN
# ..       ...        ...            ...
# 12         0          5             Mr
# 13         0          5             Mr
# 14         0          5             Mr
# 15         0          5             Mr
# 16         1          5             Mr
#
# [1309 rows x 14 columns]

# %%
df.head(4)
# Out:
#    ticket                    fname    lname  gender      age age_category  \
# 0   24160         Elisabeth Walton    Allen  female  29.0000     teen_age
# 1  113781            Hudson Trevor  Allison    male   0.9167         baby
# 2  113781            Helen Loraine  Allison  female   2.0000         baby
# 3  113781  Hudson Joshua Creighton  Allison    male  30.0000     teen_age
#
#    pclass  family_cnt comp_type     embarked      fare  survived  companion
# 0       1           0   friends  Southampton  211.3375         1          5
# 1       1           3    family  Southampton  151.5500         1          5
# 2       1           3    family  Southampton  151.5500         0          5
# 3       1           3    family  Southampton  151.5500         0          5

# %%
sns.pairplot(df)

# %%
sns.pairplot(df[['fare','pclass','age']])

# %%
df.corr(numeric_only=True)
# Out:
#                  age    pclass  family_cnt      fare  survived  companion
# age         1.000000 -0.378663   -0.193160  0.180939 -0.043844        NaN
# pclass     -0.378663  1.000000    0.046349 -0.569440 -0.321205        NaN
# family_cnt -0.193160  0.046349    1.000000  0.222947  0.023038        NaN
# fare        0.180939 -0.569440    0.222947  1.000000  0.241627        NaN
# survived   -0.043844 -0.321205    0.023038  0.241627  1.000000        NaN
# companion        NaN       NaN         NaN       NaN       NaN        NaN
